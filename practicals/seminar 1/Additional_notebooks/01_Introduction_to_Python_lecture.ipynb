# %% [markdown]
# # Python для анализа данных
#
# ## Лекция 1: Введение в Python
#
# **Автор** Полина Полунина
#
# **tg:** @ppolunina

# %% [markdown]
# # Почему Python?
#
# **Python** - высокоуровневый язык программирования общего назначения, ориентированный на повышение производительности разработчика и читаемости кода. Синтаксис ядра Python минималистичен. В то же время стандартная библиотека включает большой объём полезных функций. (Wiki)
#
# * Python и его библиотеки, в основном, open-source, т.е. доступны бесплатно.
# * Для Python написано или адаптировано под него большое количество различных библиотек под любые задачи.
#
# **Python** - это свободный интерпретируемый объектно-ориентированный расширяемый встраиваемый язык программирования очень высокого уровня (Г.Россум, Ф.Л.Дж.Дрейк, Д.С.Откидач "Язык программирования Python").
#
# ----------------------------

# %% [markdown]
# # Anaconda
#
# Это набор python + библиотеки для анализа данных, в том числе  jupyter notebook
#
# Наиболее используемые библиотеки для анализа данных:
#  - <a href="http://numpy.org">Numpy</a> - векторные/научные вычисления. Пакет содержит функциональные средства для работы с многомерными массивами и высокоуровневыми математическими функциями.
#
#  - <a href="http://numpy.org">SciPy</a> - научные вычисления. Методы оптимизации, интегрирования, модули обработки сигналов и изображений, статистика, линейная алгебра, сплайны, кластеризация и многое другое.
#
#  -  <a href="http://pandas.pydata.org/">Pandas</a> - библиотека для обработки и анализа данных. Предназначена для данных разной природы - матричных, панельных данных, временных рядов. Претендует на звание самого мощного и гибкого средства для анализа данных с открытым исходным кодом.
#
#  - <a href="http://scikit-learn.org/stable/">Scikit-learn</a> - реализация очень многих методов машинного обучения и интеллекуального анализа данных (data mining) с отличной документацией.
#
#  - <a href="http://http://matplotlib.org/">matplotlib</a> - библиотека для визуализации данных, в основном двухмерная графика.

# %% [markdown]
# # Установка Anaconda

# %% [markdown]
# - <a href="https://www.anaconda.com/distribution/">Anaconda distribution</a> - ссылка на страницу для скачивания
# - выберите свою операционную систему, скачайте соответствующий установщик, **версия python 3.7**
# - для **Windows** поставьте галочку в пункте **Add Anaconda to my PATH environment variable**
# - если ее не поставить, то придется руками прописывать пути к Python (!)
# <img src="anaconda_install_1.jpg">

# %% [markdown]
# # Работа с терминалом
#
# - терминал будем использовать для запуска jupyter notebook
# - jupyter notebook будем запускать из папки, в которой будем хранить материалы курса
# - создаем соответствующую папку, например, на рабочем столе папка "python_for_ds"
# - запускаем терминал:
#     - **Windows**: cmd
#     - **macOS**: Terminal
#     - **Linux**: Terminal
# - переходим в папку командой: **cd users/*user_name*/desktop/python_for_ds** (вместо user_name нужно подставить имя вашей учетной записи на компьютере)
# - запускаем jupyter notebook: в терминале пишем **jupyter notebook**
# - если все шаги выполнены верно, то в браузере откроется jupyter notebook
# - вы увидите список файлов из вашей рабочей папки (если она не пуста)
# - создайте новый ноутбук

# %% [markdown]
# # Jupyter Notebook
#
# **Jupyter Notebook** - это среда, в которой можно писать код,полноценные текстовые блоки с формулами и картинками.
#
# Ноутбук имеет расширение .ipynb, читать и запускать его можно через Jupyter Notebook.
#
# Скачать ноутбук можно не только в форматах .ipynb и .py, но и в виде html-страницы или pdf-документа.
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.18.44.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.18.44.png)

# %% [markdown]
# # Как устроен Jupyter Notebook
#
# - Любой ноутбук состоит из ячеек. Даже текущий текст написан в ячейке.<br>
#
# ## Создание ячейки.
# - Чтобы создать новую ячейку, можно воспользоваться одной из следующих опций: <br>
#     1) воспользоваться кнопкой "+" на верхней панели управления;<br>
#     ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.53.18.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.53.18.png)
#     2) с клавиатуры нажать на букву "B", и появится новая ячейка после текущей активной; <br>
#     3) с клавиатуры нажать на букву "A", и появится новая ячейка перед текущей активной. <br>
#
# ## Изменение типа ячейки
# - Ячейки бывают двух типов: <br>
#     1) Кодовая<br>
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.02.41.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.02.41.png)
#     2) Текстовая
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.03.36.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.03.36.png)
# <br> <br>
# - Смена типа ячейки осуществляется через верхнюю панель управления, необходимо нажать на ячейку и выбрать ее тип:
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.25.37.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.25.37.png)
#
# ## Редактирование ячейки
#
# - Ячейка, которая не активна, выглядит следующим образом:
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.35.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.35.png)
# - Ячейка активируется одним нажатием курсора и выглядит следующим образом:
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.47.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.47.png)
# - Ячейка переходит в режим редактирования двойным нажатием курсора и выглядит следующим образом:
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.53.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2015.58.53.png)
#
# ## Запуск ячейки с кодом
# - Ячейка с кодом, которая еще не была ни разу запущена. Признак - слева в квадратных скобках [] пусто.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.03.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.03.png)
#
# - В последних версиях Jupyter Notebook при приближении к ячейке слева появляется кнопка проигрывания, которая запускает ячейку.
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.09.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.09.png)
#
# - Запустить код можно также из панельной строки. Запускается код ячейки, которая была выбрана!
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.20.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.20.png)
#
# - Если ячейка успешно запущена, то слева в квадратных скобках появляется число. Вот результат успешного выполнения команды:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.35.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.15.35.png)
#
# ## Прерывание работы
#
# Иногда требуется искусственно остановить работу ячейки.
#
# - Можно нажать кнопку стоп при работе активной ячейки.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.06.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.06.png)
# - Можно воспользоваться опцией в меню Kernel - Interrupt
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.13.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.13.png)
# - Можно радикально "перезагрузить" ноутбук в меню Kernel - Restart and Clear Output
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.23.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-10-28%20%D0%B2%2016.35.23.png)

# %% [markdown]
# -----------------------------------------------------

# %% [markdown]
# # Подключение к удаленным серверам
#
# Бывают ситуации, когда мощностей вашего рабочего компьютера не хватает для выполнения поставленной задачи, например:
#
# - данные не помещаются полностью в оперативную память
# - алгоритм обучается слишком медленно и хочется его ускорить
#
# В таких ситуациях используют удаленные сервера с мощностями, значительно превышающими мощность вашего ПК. Это может быть:
#
# - рабочий сервер (часть биг дата инфраструктуры)
# - сторонний облачный сервис (google, amazon, microsoft...)
#
# Давайте разберемся как подключиться к удаленному серверу:
#
# - **macOS**, **Linux**, **Windows 10**: подключаемся через терминал по ssh
# - **Windows < 10**: придется установить дополнительную программу, например, Putty

# %% [markdown]
# ## Что такое SSH?
#
# Secure Shell (Secure Socket Shell) это протокол, который позволяет защищенно подключаться к удаленному компьютеру или серверу через тексовый интерфейс
#
# После того как защищенное SSH соединение установлено, запускается shell-сессия, через которую можно выполнять команды на удаленной машине со своего ПК.

# %% [markdown]
# # Правила оформления кода
#
# - существуют стандарты написания кода, они описаны в документах под общим названием PEP
# - нас, как аналитиков, интересуют три основных стандарта: PEP8, PEP20, PEP257
# - <a href="https://www.python.org/dev/peps/pep-0008/">PEP8</a> - как писать код так, чтобы его было удобно читать
# - <a href="https://www.python.org/dev/peps/pep-0020/">PEP20</a> - общие правила написания кода, так называемый *Zen of Python* (import this)
# - <a href="https://www.python.org/dev/peps/pep-0257/">PEP257</a> - правила написания коментариев и документации к коду

# %% [markdown]
# # Основы Python
#
# Для прикладных целей важно овладеть несколькими аспектами:
#
# - Стандартные функции языка
# - Переменные и типы данных
# - Основные конструкции
# - Написание пользовательских функций
# - Загрузка и использование библиотек

# %% [markdown]
# ## Стандартные функции языка
#
# Функции - это маленькие программки, которые умеют выполнять какую-то операцию <br />
# Функции <b>вызываются</b>, после имени функции следуют круглые скобки, в которых указываются <b>аргументы</b> (над каким объектом будет выполнена операция) и <b>параметры </b> (с какими условиями)

# %% [markdown]
# ### print()
# Функция для вывода содержимого на экран. <br>
# **Обязательно**: передать хотя бы какой-то объект, который нужно напечатать.
#
# Ее полный синтаксис:
#
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)¶
# - objects: один или несколько объектов для вывода, перечисленные через запятую
# - sep: разделитель между несколькими объектами; стандартно установлен пробел
# - end: окончание строки; стандартно установлен перевод на новую строчку '\n'

# %%
print(5)

# %%
print?

# %%
print(5,6,7,8)

# %%
print(5, 6, 7, 8, sep='_')

# %%
print("Апрель")

# %%
print('Переменная равна: {}'.format(5))

# %% [markdown]
# #### Задача 1
#
# Выведите на экран фразу "Hello, world!"

# %%
print(...)

# %% [markdown]
# ### input()
# Функция для ввода данных в программу с клавиатуры. <br>
# Обязательных аргументов нет. Можно передавать строчку, которая будет выведена перед ячейкой ввода.

# %%
name = input()
print('Меня зовут ', name)

# %% [markdown]
# А здесь небольшое преобразование позволит вывести перед ячейкой ввода нужный текст

# %%
name = input('Введите ваше имя: ')
print('Меня зовут ', name)

# %% [markdown]
# ### Арифметические операции
# - Сложение: +
# - Вычитание: -
# - Умножение: *
# - Деление: /
# - Возведение в степень: **
# - Целочисленное деление: //
# - Остаток от деления: %

# %%
print('Работаем с числами', 5, 'и', 2)
print(5 + 2)
print(5 - 2)
print(5 * 2)
print(5 / 2)
print(5 // 2)
print('Результат остатка от деления:', 5 % 2)
print('Результат возведения в степени:', 5 ** 2)

# %% [markdown]
# Для выведения результата на экран не обязательно прописывать print(), можно просто выполнить ячейку, при этом отобразиться результат только последней строчки кода:

# %%
5 + 2

# %%
5 + 2
5 * 2

# %%
print(5 + 2)
5 * 2

# %%
print(5 + 2)
print(5 * 2)

# %% [markdown]
# #### Задача 2
#
# Найти площадь круга с радиусом $R = 5$. Подсказка: площадь круга вычисляется по формуле $S = \pi * R^2, \pi$ ~ 3.14

# %%
3.14 * 5 ** 2

# %% [markdown]
# ### Переменные и типы переменных
#
# Результаты операций и манипуляций иногда нужно сохранять, поэтому мы определяем переменные - именованные объекты, которым присваиваем значения.

# %%
# Задаем значения переменных
S = 100
pi_ = 3.14
r = (S / pi_) ** (0.5)

# %%
# Вывести на печать радиус 
print('r', round(r,2), sep='=')

# %% [markdown]
# #### Задача 3
#
# Найти площадь круга с радиусом $R = 5$. Подсказка: площадь круга вычисляется по формуле $S = \pi * R^2, \pi$ ~ 3.14
#
# - Создайте переменную r со значением 5
# - Создайте переменную pi_ со значением 3.14
# - Сохраните результат вычисления в переменную S
# - Выведите на печать результаты

# %%
# Место для решения
...

# %% [markdown]
# ### Основные типы данных:
#
# - int (integer numbers) - целые числа
# - float (floating-point numbers) - числа с плавающей точкой
# - str (string) - строки
# - bool (boolean) - логический тип

# %% [markdown]
# Функция **type** позволяет определить, какого типа переменная нам дана или какого типа переменную мы записали.

# %%
print(type(r))
print(type(S))

# %%
text = 'Площадь круга'
print(type(text))

# %%
x = True
print(type(x))

# %% [markdown]
# Если нужно поменять тип переменной, то полезны функции:
#
# - int() - возвращает целочисленную переменную
# - float() - возвращает нецелочисленную переменную
# - bool() - возвращает булеву переменную
# - str() - возвращает строковую переменную

# %%
# Конкатенация строк
'Мое имя' + ' ' + 'Полина'

# %%
print(r, type(r))
r_new = str(r)
print(r_new, type(r_new))
print('Радиус ' +  'круга: ' + r_new)

# %%
print(10 - float(r_new))

# %% [markdown]
# ##  Базовые конструкции
#
# ### Логические выражения
#
# По аналогии с арифметическими выражениями существуют логические выражения, которые могут быть истинными или ложными. Простое логическое выражение имеет вид <br />
#
# <арифметическое выражение> <знак сравнения> <арифметическое выражение>. <br />
#
# Например, если у нас есть переменные x и y с какими-то значениями, то логическое выражение <br /> x + y < 3y <br /> в качестве первого арифметического выражения имеет x + y, в качестве знака сравнения < (меньше), а второе арифметическое выражение в нём 3y.
#
# Логические выражения:
# - $<$   меньше
# - $>$  больше
# - $<=$  меньше или равно
# - $>=$  больше или равно
# - $==$  равно
# - $!=$  не равно

# %%
2 != 3

# %%
a=2
b=3

a != b

# %%
x = 2 * 2 == 5
print(type(x))
print(x)
print(int(x))

# %%
x = 2 * 2 != 5
print(type(x))
print(x)
print(int(x))

# %% [markdown]
# Чтобы записать сложное логическое выражение, часто бывает необходимо воспользоваться логическими связками "и", "или" и "не". В Питоне они обозначаются как and, or и not соответственно. Операции and и or являеются бинарными, т.е. должны быть записаны между операндами, например x < 3 or y > 2. Операция not - унарная и должна быть записана перед единственным своим операндом.

# %%
x = 4
y = 5
print(x > 3 and y > 3)
print(x > y or x == y)
print(not (x > y))

# %%
a = 1
b = 2
c = 3
d = 4

((a == d) and (a > c)) != 4

# %%
((False) and (False)) != 4

# %%
False != 4

# %% [markdown]
# #### Задача 4
#
# Сравните $2^3$ и $3^2$. Результат распечатайте

# %%
# Место для решения
...

# %% [markdown]
# #### Задача 5
#
# Напишите логическое выражение для проверки попадания введенного числа в интервал от 0 до 10.

# %%
# Место для решения
...

# %% [markdown]
# ### Условный оператор

# %% [markdown]
# Наиболее частое применение логические выражения находят в условных операторах.
#
# Синтаксис в питоне: <br />
# **if** условие_1:<br />
# &emsp; команды<br />
# **elif** условие_2:<br />
# &emsp; команды<br />
# **elif** условие_3:<br />
# &emsp; команды<br />
# &emsp; ... <br />
# **elif** условие_N:<br />
# &emsp; команды<br />
# **else**: <br />
# &emsp; команды<br />

# %% [markdown]
# **Пример**

# %%
x = 2 ** 3   # 8
y = 3 ** 2   # 9

if x > y:
    print('X больше Y')
    print(x - y)
else:
    print(' ')
    print('Y не меньше, чем X')

# %%
x = int(input('Введите число X: '))
y = int(input('Введите число Y: '))

if x > y:
    print('X больше Y')
    print('x - y = ', x - y)
elif y > x:
    print('Y больше X')
    print('y - x = ', y - x)
else:
    print('X равно Y')

# %% [markdown]
# #### Задача 6
#
# 1) Друзья позвали вас поехать на водохранилище купаться на выходных. Вы с удовольствием поедете, если погода будет хорошей. Вы решили посмотреть прогноз погоды и оказалось, что на выходных температура воздуха будет 26 градусов. Выведите на экран сообщение, которое вы решили отправить своим друзьям.
#
# Если температура выше 23 градусов, то должна появиться строчка "На выходных будет тепло, поехали купаться!", в противном случае - "К сожалению, будет слишком холодно и я не поеду"

# %%
# Место для решения
...

# %% [markdown]
# 2) Друзья позвали вас поехать на водохранилище купаться на выходных. Но вот незадача, вы не помните есть ли у вас плавки :) Вы с удовольствием поедете, если погода будет хорошей. При этом если окажется, что плавок у вас нет, то придется сначала заехать в магазин. Вы решили посмотреть прогноз погоды и проверить есть ли у вас плавки. Выведите на экран сообщение, которое вы решили отправить своим друзьям.
#
# Если температура выше 23 градусов и плавки у вас есть, то должна появиться строчка "На выходных будет тепло, поехали купаться!". Если при этом у вас нет плавок, должна появиться строчка "Конечно поехали, только заедем в магазин по пути". В противном случае - "К сожалению, будет слишком холодно и я не поеду"

# %%
# Введите любое число
temperature = int(input('Температура воздуха: '))
# Введите да или нет
plavki = input('Плавки есть? ')

if temperature > 23 and plavki == 'да':
    print("На выходных будет тепло, поехали купаться!")
    
elif temperature > 23 and plavki == 'нет':
    print("Конечно поехали, только заедем в магазин по пути")
    
else:
    print("К сожалению, будет слишком холодно и я не поеду")

# %% [markdown]
# ### Цикл while
#
# Циклические конструкции используются для многократного повторения одних и тех же действий.
#
# В цикле while команды выполняются до тех пор, пока некоторое заданное условие верно. При этом, если в теле цикла прямо не прописана процедура изменения переменной, заданной в условии, то получится бесконечный цикл :)
#
# Структура цикла while:

# %%
candies_num = 3

while candies_num > 0:
    print('Конфеты есть')
    candies_num -=1        #  то же самое, что и candies_num = candies_num - 1

# %% [markdown]
# #### Задача 7
#
# По данному целому числу N распечатайте все квадраты натуральных чисел, не превосходящие N, в порядке возрастания.

# %%
# Место для решения
...

# %% [markdown]
# ### Функция range(n)
#
# Функция range выдает последовательность чисел в зависимости от заданных параметров
#
# Синтаксис функции:

# %%
range?

# %%
print(range(10))

# %%
range(3, 10)

# %%
range(3, 12, 2)

# %%
for i in range(3, 12, 2):
    print(i)

# %% [markdown]
# ## Цикл for
#
# Команды в цикле for выполняются для заданного списка объектов и повторяются столько раз, сколько этих объектов.
#
# Дословно это работает так:
#
# *Питон, для каждого объекта из списка объектов выполни, пожалуйста, вот это действие* :)

# %%
# Перекличка :)
for i in range(1, 5): 
    print(i)

# %%
for animal in ['кошка', 'собака', 'жираф', 'хомяк']:
    print(animal)

# %% [markdown]
# #### Задача 8
#
# По данному целому числу N распечатайте все квадраты натуральных чисел, не превосходящие N, в порядке возрастания с использованием цикла for

# %%
# Место для решения
...
